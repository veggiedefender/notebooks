# %%
# %matplotlib inline

import secrets
import numpy as np
import matplotlib.pyplot as plt

# %%
TRIALS = 1_000_000

# %%
def random_walk():
    num = 0
    for i in range(100):
        num += secrets.choice([-1, 1])
    return num

# %%
results = [random_walk() for i in range(TRIALS)]

# %%
plt.style.use("seaborn")
plt.ylabel("Frequency")
plt.xlabel("Result of random walk")
plt.hist(results, bins=np.arange(-100, 100, 2));
plt.savefig("figure.png", dpi=300)
